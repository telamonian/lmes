# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2

from copy import deepcopy
import os,sys
from pathlib import Path

# numpy.set_printoptions(precision=3, threshold=1e6, linewidth=1e6)

from lm_anal.src.main import Sim, Sims
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
fPath = '/Users/tel/temp_data/mcz_1.0e+05_-_mcn_1.0e+02_-_phi_1.0e+00_-_theta_1.0e+01_-_tiles_12_-_rep_2'

sims = Sims(rootPath=fPath)

# %%
sims.peek().oparamFPTs.peek().points
# Out:
# array([(0, -27.0, -38.0, 4.503394398254552),
#        (0, -22.5, -38.0, 48.816795277079336),
#        (0, -18.0, -38.0, 214.79389921914913),
#        (0, -13.5, -38.0, 1209.2896526038096),
#        (0, -9.0, -38.0, 3615.776061285391),
#        (0, -4.5, -38.0, 5134.402007025255),
#        (0, 0.0, -38.0, 5596.498187657528),
#        (0, 4.5, -38.0, 6491.937897682732),
#        (0, 9.0, -38.0, 6881.454171543696),
#        (0, 13.5, -38.0, 7294.341421836319),
#        (0, 18.0, -38.0, 7659.058492928135),
#        (0, 22.5, -38.0, 7812.2396627866965),
#        (0, 27.0, -38.0, 7890.362059414564),
#        (0, 27.0, 38.0, 4.512989229764512),
#        (0, 22.5, 38.0, 48.19872497388498),
#        (0, 18.0, 38.0, 157.6098306646039),
#        (0, 13.5, 38.0, 747.0705973502223),
#        (0, 9.0, 38.0, 1875.1471993490582),
#        (0, 4.5, 38.0, 2793.969327030097),
#        (0, 0.0, 38.0, 3213.0647260846117),
#        (0, -4.5, 38.0, 3630.763140475611),
#        (0, -9.0, 38.0, 3993.8394545231718),
#        (0, -13.5, 38.0, 4473.100189065953),
#        (0, -18.0, 38.0, 4607.293194737931),
#        (0, -22.5, 38.0, 4745.511990580069),
#        (0, -27.0, 38.0, 4745.511990580069)],
#       dtype=[('oparam_id', '<i8'), ('count', '<f8'), ('initial_count', '<f8'), ('time', '<f8')])

# %%
# %debug
# Out:
# > /Users/tel/git/lm/utils/python/lm_anal/lm_anal/src/io/hdf5/hdf5IO.py(243)_rff()
#     242                 # the integer keys in Lattice Microbes hdf5 files are usually in %07d format, so if the key isn't found try putting the key into that format
# --> 243                 del container[int(key)]
#     244                 key = '%07d' % key
#
# ipdb> self.file

# %%
print(sims.peek().oparamFPTs.po)
# Out:
# .lmint

# %%
sims.peek().oparamFPTs.regen()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/tel/git/lm/utils/python/lm_anal/lm_anal/src/io/hdf5/hdf5IO.py in _rff(self, container, full, keys)
#     239             try:
# --> 240                 self.input(full=full, hdf5Path=os.path.join(self.hdf5RootPath, str(key)), subCon=subCon)
#     241             except KeyError:
#
# /Users/tel/git/lm/utils/python/lm_anal/lm_anal/src/io/hdf5/hdf5IO.py in input(self, full, hdf5Path, subCon)
#      55         for spec in self.hdf5Specs:
# ---> 56             self.inputBySpec(full, hdf5Path, spec, subCon)
#      57
#
# /Users/tel/git/lm/utils/python/lm_anal/lm_anal/src/io/hdf5/hdf5IO.py in inputBySpec(self, full, hdf5Path, hdf5Spec, subCon)
#      62             elif hdf5Spec.type=='dataset':
# ---> 63                 self.inputArray(hdf5Path=hdf5Path, hdf5Spec=hdf5Spec, subCon=subCon)
#      64             elif hdf5Spec.type=='embedded':
#
# /Users/tel/git/lm/utils/python/lm_anal/lm_anal/src/io/hdf5/hdf5IO.py in inputArray(self, hdf5Path, hdf5Spec, subCon)
#      75     def inputArray(self, hdf5Path, hdf5Spec, subCon):
# ---> 76         subCon.setArray(name=hdf5Spec.name, val=self.file[hdf5Path][hdf5Spec.subKey])
#      77
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/Users/travis/build/MacPython/h5py-wheels/h5py/h5py/_objects.c:2405)()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/Users/travis/build/MacPython/h5py-wheels/h5py/h5py/_objects.c:2362)()
#
# /usr/local/lib/python3.4/site-packages/h5py/_hl/group.py in __getitem__(self, name)
#     159         else:
# --> 160             oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     161
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/Users/travis/build/MacPython/h5py-wheels/h5py/h5py/_objects.c:2405)()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/Users/travis/build/MacPython/h5py-wheels/h5py/h5py/_objects.c:2362)()
#
# h5py/h5o.pyx in h5py.h5o.open (/Users/travis/build/MacPython/h5py-wheels/h5py/h5py/h5o.c:3456)()
#
# KeyError: 'Unable to open object (Component not found)'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-9f5983fa5248> in <module>()
# ----> 1 sims.peek().oparamFPTs.regen()
#
# /Users/tel/git/lm/utils/python/lm_anal/lm_anal/src/datum/data.py in regen(self, fPath, overwriteInt)
#     255             self.dfint(raiseIfNotExists=True)
#     256
# --> 257         self.resetMap()
#     258
#     259     def resetMap(self):
#
# /Users/tel/git/lm/utils/python/lm_anal/lm_anal/src/datum/data.py in resetMap(self)
#     264             pass
#     265         # poke the .map lazy loader
# --> 266         self.map
#     267
#     268     def transform(self, *dataToTransform, **transformKwargs):
#
# /Users/tel/git/lm/utils/python/lm_anal/lm_anal/src/datum/data.py in __get__(self, obj, ObjType)
#      30                 transformKwargs = obj.dataToTransformDict.copy()
#      31                 transformKwargs.update(obj.transformKwargs)
# ---> 32                 lzTransforms(srcs=obj.dataToTransform, dsts=obj, **transformKwargs)
#      33                 # record the object's point-of-origin as a transform
#      34                 obj.po = 'transform'
#
# /Users/tel/git/lm/utils/python/lm_anal/lm_anal/src/helper/importHelper.py in __call__(self, **kwargs)
#      75         same as getAttr, with an extra call and possibly some kwargs
#      76         '''
# ---> 77         return self.getAttr()(**kwargs)
#      78
#      79 # ShallowImport stuff
#
# /Users/tel/git/lm/utils/python/lm_anal/lm_anal/src/transform/transforms.py in __init__(self, srcs, dsts, **kwargs)
#      67         if not hasattr(self, 'transform'):
#      68             raise
# ---> 69         self.transform.tfd(srcs, dsts, **kwargs)
#      70
#
# /Users/tel/git/lm/utils/python/lm_anal/lm_anal/src/transform/fflux/pcloud/ffluxOutputToOParamFPTT.py in tfd(self, srcs, dsts, keys, **kwargs)
#      59                 dstsWithDatum = {dstDatum} | dsts
#      60
# ---> 61                 pT.transformProperties(srcs=srcsWithDatum, dsts=dstsWithDatum, **kwargs)
#
# /Users/tel/git/lm/utils/python/lm_anal/lm_anal/src/propertyTransform/propertyTransforms.py in transformProperties(self, srcs, dsts, **kwargs)
#     125         dstDict = self.buildDict(dsts, kind='dst')
#     126         for propTran in self.propertyTransforms:
# --> 127             propTran.ptfd(srcDict=srcDict, dstDict=dstDict, **kwargs)
#     128
#     129 #     def getBaseClass(self, datumType):
#
# /Users/tel/git/lm/utils/python/lm_anal/lm_anal/src/propertyTransform/fflux/pcloud/basinsToOParamFPTPT.py in ptfd(self, srcDict, dstDict, **kwargs)
#      27         oparamFPT = np.zeros(len(edges)*len(directionIDs), dtype=dstDatum.propertySpecs['points']['dtype'])
#      28         for directionID,direction in zip(directionIDs, directions):
# ---> 29             initSpeciesCount = reactionModel.initial_species_counts if direction=='FORWARD' else reactionModel.initial_species_counts_backward
#      30             initOParamCount = oparam.calc(np.atleast_2d(initSpeciesCount))
#      31
#
# /Users/tel/git/lm/utils/python/lm_anal/lm_anal/src/datum/dataSingleton.py in __getattr__(self, attr)
#      21         pass calls to unknown attributes through to the .singleton Datum
#      22         '''
# ---> 23         return self.singleton.__getattribute__(attr)
#
# /Users/tel/git/lm/utils/python/lm_anal/lm_anal/src/datum/dataSingleton.py in singleton(self)
#      15         property that returns the single Datum belonging to this Data
#      16         '''
# ---> 17         return self.map[self.singletonKey]
#      18
#      19     def __getattr__(self, attr):
#
# /Users/tel/git/lm/utils/python/lm_anal/lm_anal/src/datum/data.py in __get__(self, obj, ObjType)
#      20             if obj.readIO is not None:
#      21                 # read the data in from file
# ---> 22                 obj.readIO.rff(container=obj, full=True)
#      23                 # record the object's point-of-origin
#      24                 if obj.readIO==obj.intIO:
#
# /Users/tel/git/lm/utils/python/lm_anal/lm_anal/src/io/hdf5/hdf5IO.py in rff(self, full, keys, **kwargs)
#     250         rff (read from file) for hdf5 files
#     251         '''
# --> 252         return self.wrapperHDF5(self._rff, full=full, keys=keys, **kwargs)
#     253
#     254     def sff(self, full=False, keys=None):
#
# /Users/tel/git/lm/utils/python/lm_anal/lm_anal/src/io/hdf5/hdf5IO.py in wrapperHDF5(self, func, mode, **kwargs)
#     294             try:
#     295                 with h5py.File(self.fPath, mode) as self.file:
# --> 296                     retVal = func(**kwargs)
#     297             except OSError:
#     298                 self.file = None
#
# /Users/tel/git/lm/utils/python/lm_anal/lm_anal/src/io/hdf5/hdf5IO.py in _rff(self, container, full, keys)
#     241             except KeyError:
#     242                 # the integer keys in Lattice Microbes hdf5 files are usually in %07d format, so if the key isn't found try putting the key into that format
# --> 243                 del container[int(key)]
#     244                 key = '%07d' % key
#     245                 subCon = container.initDatum(key=int(key), full=full)
#
# ValueError: invalid literal for int() with base 10: 'Reaction'

# %%
# %debug
# Out:
# > /Users/tel/git/lm/utils/python/lm_anal/lm_anal/src/io/hdf5/hdf5IO.py(243)_rff()
#     242                 # the integer keys in Lattice Microbes hdf5 files are usually in %07d format, so if the key isn't found try putting the key into that format
# --> 243                 del container[int(key)]
#     244                 key = '%07d' % key
#
# ipdb> key
# 'Reaction'
# ipdb> self
# <lm_anal.src.io.hdf5.model.reactionModelIO.ReactionModelIO object at 0x114ac6668>

# %%
sims.peek().oparamFPTs.peek().points
# Out:
# array([(0, -27.0, -38.0, 0.22205472396279238),
#        (0, -22.5, -38.0, 0.02048475313309893),
#        (0, -18.0, -38.0, 0.004655625712067938),
#        (0, -13.5, -38.0, 0.0008269317428184614),
#        (0, -9.0, -38.0, 0.0002765658002737329),
#        (0, -4.5, -38.0, 0.00019476464808009357),
#        (0, 0.0, -38.0, 0.00017868316337623264),
#        (0, 4.5, -38.0, 0.0001540372098070971),
#        (0, 9.0, -38.0, 0.00014531812245952559),
#        (0, 13.5, -38.0, 0.00013709256835804298),
#        (0, 18.0, -38.0, 0.0001305643508171838),
#        (0, 22.5, -38.0, 0.00012800426550704295),
#        (0, 27.0, -38.0, 0.00012673689654162668),
#        (0, 27.0, 38.0, 0.22158262497164882),
#        (0, 22.5, 38.0, 0.020747436795098207),
#        (0, 18.0, 38.0, 0.006344781894525445),
#        (0, 13.5, 38.0, 0.0013385615811235118),
#        (0, 9.0, 38.0, 0.0005332914665830724),
#        (0, 4.5, 38.0, 0.00035791373596179353),
#        (0, 0.0, 38.0, 0.00031122933561895087),
#        (0, -4.5, 38.0, 0.00027542419081323085),
#        (0, -9.0, 38.0, 0.00025038562801202806),
#        (0, -13.5, 38.0, 0.00022355859643931076),
#        (0, -18.0, 38.0, 0.0002170471810090396),
#        (0, -22.5, 38.0, 0.00021072541845537824),
#        (0, -27.0, 38.0, 0.00021072541845537824)],
#       dtype=[('oparam_id', '<i8'), ('count', '<f8'), ('initial_count', '<f8'), ('time', '<f8')])

# %%
vars(sims.peek().reactionModels)

# %%
# %debug

# %%
import ipdb
ipdb.set_trace()
bob.map

# %%
# %debug

# %%
sim.oparamFPTs[0].points
